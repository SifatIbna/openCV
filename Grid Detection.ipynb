# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
flat_chess = cv2.imread('test images/chess_board.jpg')

# %%
plt.imshow(flat_chess)

# %%
found,corners = cv2.findChessboardCorners(flat_chess,(7,7))

# %%
found
# Out:
# True

# %%
corners
# Out:
# array([[[ 227.54428,  216.6651 ]],
#
#        [[ 361.90146,  216.63124]],
#
#        [[ 495.43488,  216.73924]],
#
#        [[ 629.631  ,  216.63808]],
#
#        [[ 763.3599 ,  216.52509]],
#
#        [[ 897.76855,  216.53981]],
#
#        [[1031.5853 ,  216.64566]],
#
#        [[ 227.66309,  350.47217]],
#
#        [[ 361.86655,  350.41364]],
#
#        [[ 495.54175,  350.3514 ]],
#
#        [[ 629.50024,  350.46133]],
#
#        [[ 763.5559 ,  350.4351 ]],
#
#        [[ 897.40485,  350.60416]],
#
#        [[1031.4716 ,  350.2977 ]],
#
#        [[ 228.06909,  484.52005]],
#
#        [[ 361.4354 ,  484.3801 ]],
#
#        [[ 495.58224,  484.3565 ]],
#
#        [[ 629.82794,  484.38376]],
#
#        [[ 763.49396,  484.30597]],
#
#        [[ 897.34015,  484.67737]],
#
#        [[1031.4573 ,  484.21246]],
#
#        [[ 227.95093,  618.3557 ]],
#
#        [[ 361.81628,  618.3304 ]],
#
#        [[ 495.45743,  618.3221 ]],
#
#        [[ 629.92017,  618.1183 ]],
#
# ...

# %%
cv2.drawChessboardCorners(flat_chess,(7,7),corners,found)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
plt.imshow(flat_chess)

# %%
dots=cv2.imread('test images/dot_grid.jpg')

# %%
plt.imshow(dots)

# %%
found,corners = cv2.findCirclesGrid(dots,(25,25),cv2.CALIB_CB_SYMMETRIC_GRID)

# %%
found
# Out:
# True

# %%
cv2.drawChessboardCorners(dots)
