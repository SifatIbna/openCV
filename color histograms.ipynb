# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
batman = cv2.imread('test images/batman.jpg')
show_batman = cv2.cvtColor(batman,cv2.COLOR_BGR2RGB)

bvs = cv2.imread('test images/bvs.jpg')
show_bvs = cv2.cvtColor(bvs,cv2.COLOR_BGR2RGB)

rainbow = cv2.imread('test images/rainbow.jpg')
show_rainbow = cv2.cvtColor(rainbow,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(show_rainbow)

# %%
hist_values = cv2.calcHist([rainbow],channels=[0],mask=None,histSize=[256],ranges=[0,256])

# %%
hist_values.shape
# Out:
# (256, 1)

# %%
plt.plot(hist_values)

# %%
hist_values = cv2.calcHist([batman],channels=[2],mask=None,histSize=[256],ranges=[0,256])

# %%
plt.plot(hist_values)

# %%
img = rainbow

# %%
color = ('b','g','r')

# %%
for i,col in enumerate(color):
    histr = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color=col)
    plt.xlim([0,20])
    plt.ylim([0,5000])
plt.title('HISTOGRAM FOR RAINBOW IMAGE')
# Out:
# Text(0.5, 1.0, 'HISTOGRAM FOR RAINBOW IMAGE')

# %%
plt.imshow(show_rainbow)

# %%
rainbow = cv2.imread('test images/rainbow.jpg')
show_rainbow = cv2.cvtColor(rainbow,cv2.COLOR_BGR2RGB)

# %%
img = rainbow

# %%
img.shape
# Out:
# (163, 310, 3)

# %%
img.shape[:2]
# Out:
# (163, 310)

# %%
mask = np.zeros(img.shape[:2],np.uint8)

# %%
# plt.imshow(mask,cmap='gray')
mask[60:100,100:200] = 255

# %%
plt.imshow(mask,cmap='gray')

# %%
plt.imshow(show_rainbow)

# %%
masked_img = cv2.bitwise_and(img,img,mask=mask)

# %%
show_masked_img = cv2.bitwise_and(show_rainbow,show_rainbow,mask=mask)

# %%
plt.imshow(show_masked_img)

# %%
hist_mask_values_red = cv2.calcHist([rainbow],channels=[2],mask=mask,histSize=[256],ranges=[0,256])

# %%
hist_values_red = cv2.calcHist([rainbow],channels=[2],mask=None,histSize=[256],ranges=[0,256])

# %%
plt.plot(hist_mask_values_red)
plt.title('RED HISTOGRAM for MASKED RAINBOW')
# Out:
# Text(0.5, 1.0, 'RED HISTOGRAM for MASKED RAINBOW')

# %%
plt.plot(hist_values_red)
plt.title('RED HISTOGRAM FOR NORMAL RAINBOW')
# Out:
# Text(0.5, 1.0, 'RED HISTOGRAM FOR NORMAL RAINBOW')

# %%
gorilla = cv2.imread('test images/gorilla.jpg',0) # reading as grayscale

# %%
def display_img(img,cmap=None):
    fig = plt.figure(figsize=(10,8))
    ax = fig.add_subplot(111)
    ax.imshow(img,cmap)

# %%
display_img(gorilla,'gray')

# %%
gorilla.shape
# Out:
# (146, 344)

# %%
hist_values=cv2.calcHist([gorilla],channels=[0],mask=None,histSize=[256],ranges=[0,256])

# %%
plt.plot(hist_values)

# %%
eq_gorilla = cv2.equalizeHist(gorilla)

# %%
display_img(eq_gorilla,cmap='gray')

# %%
hist_values=cv2.calcHist([eq_gorilla],channels=[0],mask=None,histSize=[256],ranges=[0,256])

# %%
plt.plot(hist_values)

# %%
color_gorilla = cv2.imread('test images/gorilla.jpg')

# %%
show_gorilla = cv2.cvtColor(color_gorilla,cv2.COLOR_BGR2RGB)

# %%
display_img(show_gorilla)

# %%
# to equalize color images we have to convert it to HSV colorspaces

hsv = cv2.cvtColor(color_gorilla,cv2.COLOR_BGR2HSV)

# %%
hsv.shape
# Out:
# (146, 344, 3)

# %%
hsv[:,:,2]
# Out:
# array([[ 80,  76,  74, ...,  83,  84,  87],
#        [ 84,  77,  69, ...,  83,  82,  86],
#        [ 90,  80,  68, ...,  80,  81,  84],
#        ...,
#        [ 26,  26,  58, ...,  70,  76,  83],
#        [ 21,  44,  61, ...,  72,  64,  68],
#        [ 30,  52,  68, ...,  99,  99, 108]], dtype=uint8)

# %%
hsv[:,:,2] = cv2.equalizeHist(hsv[:,:,2]) # grabbing value channel

# %%
eq_color_gorilla = cv2.cvtColor(hsv,cv2.COLOR_HSV2RGB)

# %%
display_img(eq_color_gorilla)
