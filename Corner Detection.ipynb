# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
flat_chess = cv2.imread('test images/chess_board.jpg')
flat_chess = cv2.cvtColor(flat_chess,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(flat_chess)

# %%
gray_flat_chess = cv2.cvtColor(flat_chess,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray_flat_chess,cmap='gray')

# %%
real_chess = cv2.imread('test images/chess_board2.jpg')
real_chess = cv2.cvtColor(real_chess,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(real_chess)

# %%
gray_real_chess = cv2.cvtColor(real_chess,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray_real_chess,cmap='gray')

# %%
gray = np.float32(gray_flat_chess)

# %%
gray
# Out:
# array([[255., 255., 255., ..., 255., 255., 255.],
#        [255., 255., 255., ..., 255., 255., 255.],
#        [255., 255., 255., ..., 255., 255., 255.],
#        ...,
#        [255., 255., 255., ..., 255., 255., 255.],
#        [255., 255., 255., ..., 255., 255., 255.],
#        [255., 255., 255., ..., 255., 255., 255.]], dtype=float32)

# %%
dst = cv2.cornerHarris(src=gray,blockSize=2,ksize=3,k=0.04)

# %%
dst = cv2.dilate(dst,None)

# %%
flat_chess[dst>0.01*dst.max()] = [255,0,0]

# %%
plt.imshow(flat_chess)

# %%
gray = np.float32(gray_real_chess)

# %%
dst = cv2.cornerHarris(src=gray,blockSize=2,ksize=3,k=0.04)

# %%
dst = cv2.dilate(dst,None)

# %%
real_chess[dst>0.01*dst.max()] = [255,0,0]

# %%
plt.imshow(real_chess)

# %%
## CORNER DETECTION USING Shi-Tomasi Algorithm
flat_chess = cv2.imread('test images/chess_board.jpg')
flat_chess = cv2.cvtColor(flat_chess,cv2.COLOR_BGR2RGB)

real_chess = cv2.imread('test images/chess_board2.jpg')
real_chess = cv2.cvtColor(real_chess,cv2.COLOR_BGR2RGB)

gray_flat_chess = cv2.cvtColor(flat_chess,cv2.COLOR_BGR2GRAY)
gray_real_chess = cv2.cvtColor(real_chess,cv2.COLOR_BGR2GRAY)

# %%
corners = cv2.goodFeaturesToTrack(gray_flat_chess,1000,0.01,10)

# %%
corners
# Out:
# array([[[ 680., 1189.]],
#
#        [[ 704.,   48.]],
#
#        [[1207.,  960.]],
#
#        [[  58.,  549.]],
#
#        [[  55.,  407.]],
#
#        [[1187.,  960.]],
#
#        [[ 166.,   49.]],
#
#        [[1190.,  425.]],
#
#        [[ 824., 1175.]],
#
#        [[ 151., 1182.]],
#
#        [[ 554., 1177.]],
#
#        [[1088., 1177.]],
#
#        [[ 426., 1181.]],
#
#        [[ 552.,   42.]],
#
#        [[ 978.,   38.]],
#
#        [[1192.,  812.]],
#
#        [[  67.,  672.]],
#
#        [[1107.,   60.]],
#
#        [[  59., 1090.]],
#
#        [[ 413.,   47.]],
#
#        [[ 822.,   58.]],
#
#        [[ 955., 1195.]],
#
#        [[ 305.,   61.]],
#
#        [[  62.,  805.]],
#
#        [[1181.,  287.]],
#
#        [[1202.,  697.]],
#
#        [[  56.,  821.]],
#
#        [[ 141., 1180.]],
#
#        [[  66.,  683.]],
#
#        [[ 552.,   60.]],
#
#        [[1202.,  563.]],
#
#        [[  54.,  293.]],
#
#        [[ 158., 1196.]],
#
#        [[1188., 1096.]],
#
# ...

# %%
corners = np.int0(corners)

# %%
for i in corners:
    x,y = i.ravel()
    cv2.circle(flat_chess,(x,y),3,(255,0,0),-1)

# %%
plt.imshow(flat_chess)

# %%
corners = cv2.goodFeaturesToTrack(gray_real_chess,100,0.01,10)

# %%
corners = np.int0(corners)

# %%
for i in corners:
    x,y = i.ravel()
    cv2.circle(real_chess,(x,y),3,(255,0,0),-1)

# %%
plt.imshow(real_chess)
